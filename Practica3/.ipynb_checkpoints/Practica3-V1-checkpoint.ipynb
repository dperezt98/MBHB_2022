# %% [markdown]
# # PRÁCTICA 3 - ALGORITMOS DE OPTIMIZACIÓN BASADO EN HORMIGAS

# %% [markdown]
# # Base

# %%
import os 
import sys
import time
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, clear_output # Nos permitara mostrar la evolucion del algoritmo de hormigas
import networkx as nx

# %%
def tsp_to_matrix(path):
    """
    Convierte un archivo .tsp a una matriz con todas las coordenadas encontradas en el mismo. Cada fila de la matriz correspondera
    a una lista de dos posiciones donde se guardara la coordenada x e y
    
    Parametros
        path : str
            Ruta donde se encuentra el archivo .tsp
            
    Return
        Devuelve un numpy array
    """
    # Comprobamos que exista el fichero
    if os.path.isfile(path):

        # Convertimos los datos en un matriz de dos dimensiones. Donde cada entrada 
        # es la posicion de una ciudad, columna 0 es la 'x' y la columna 1 la 'y'
        with open(path) as f:
            data = f.readlines()

        # Las 5 primeras lineas de los datos se pueden descartar. Y la ultima tambien
        size_data = len(data)
        data = data[6:size_data-1]
        matrix = np.array([])
        for line in data:
            # Dividimos la linea por espacios y seleccionamos las elementos 1 y 2
            aux = line.split(' ')
            
            # Comprobamos que la variable aux tenga 3 valores: [numero, coord x, coord y]
            if len(aux) > 3:
                fix_aux = []
                for c in aux: # Character en aux
                    # Descartamos los espacios
                    if c != '' and c != ' ': 
                        fix_aux += [c]
                        
                aux = fix_aux
            
            pos = np.array([float(aux[1]), float(aux[2])])

            if len(matrix) != 0:
                matrix = np.append(matrix, [pos], axis=0)
            else:
                matrix = np.array([pos])

        return matrix
    else:
        raise Exception("The file it doesn't exist")

# %%
def euclidean_distance(coord_node_a, coord_node_b):
    """
    Calcula la distancia euclidea entre dos nodos
    
    Parametros
        coord_node_a : list
            Lista de dos posiciones con las coordenadas x e y del primer nodo. Ejemplo: [x,y]
        coord_node_b : list
            Lista de dos posiciones con las coordenadas x e y del segundo nodo. Ejemplo: [x,y]
            
    Return
        Devuelve la distancia calculada redondeada(int)
    """
    xd = coord_node_a[0] - coord_node_b[0]
    yd = coord_node_a[1] - coord_node_b[1]
    return round(np.sqrt(xd*xd + yd*yd), 3) # Redondeamos con 3 decimales

# %%
def create_sh_graph(m):
    """
    A partir de una matriz de coordenadas, se creara un grafo interconectando todos los nodos.
    
    Atributos de cada nodo:
        
        -'coord': lista de dos posiciones con las coordenadas x e y del nodo. Ejemplo: [x,y]
        -'nearest': lista de nodos mas cercanos al nodo. 
    
    Atributos de cada arista:
    
        -'distance': distancia entre los nodos que la forman
        -'pheromone': cantidad de feromonas que tiene la arista
        -'heuristic': heuristica de la arista
        
    Parametros
        m : numpy ndarray
            Matriz de coordenadas, donde cada fila es igual a una lista de dos valores: [x,y]
        init_pheromone : float
            Valor inicial de feromonas que tendra la arista
            
    Return
        Devuelve un objeto networkx
    """
    # Creamos el grafo
    g = nx.Graph()
    nodes_n = len(m) # Numero de nodos a crear
    
    # Creamos una lista de strings para nombrar los nodos y los aniadimos
    nodes_list = [] # Lista con los nombres
    for i in range(0,nodes_n):
        nodes_list += [f"Node_{i}"] # Guardamos el nombre
        g.add_node(nodes_list[i]) # Aniadimos el nodo
        g.nodes[nodes_list[i]]["coord"] = m[i] # Le asignamos las coordenadas
    
    # Aniadimos las aristas, interconectamos todos los nodos
    for i in range(0,nodes_n):
        for j in range(i+1,nodes_n):
            g.add_edge(nodes_list[i], nodes_list[j]) # Creamos la arista
            ed = euclidean_distance(g.nodes[nodes_list[i]]["coord"],g.nodes[nodes_list[j]]["coord"]) # Euclidean distance
            
            if ed != 0: # Preguntamos si la distancia entre ciudades es cero porque en el fichero a280.tsp dos ciudades tiene las mismas coordenadas
                h = 1 / ed # La  heuristica es igual a: 1 / distancia_entre_nodos
            else:
                h = 0
            g.edges[nodes_list[i], nodes_list[j]]["distance"] = ed # Guardamos
            g.edges[nodes_list[i], nodes_list[j]]["heuristic"] = h 
            g.edges[nodes_list[i], nodes_list[j]]["pheromone"] = 0 # Guardamos el valor de pheromonas inicial
            
    # Hacemos que cada nodo tenga una lista ordenada de los nodos mas cercanos
    for i in range(0,nodes_n):
        edges = list(g.edges(nodes_list[i])) # Conseguir aristas, transformamos objeto EdgeDataView a list()
        
        # Creamos una lista con las distancias de cada una de las aristas
        distances = []
        for j in range(0,len(edges)):
            edge_start = edges[j][0] # Nodo inicial de la arista - Arista j, elemento 0 (nodo inicial)
            edge_end = edges[j][1] # Nodo final de la arista - Arista j, elemento 1 (nodo final)
            edge_attributes = g.get_edge_data(edge_start,edge_end) # Devuelve un diccionario con los atributos de la arista
            distances += [edge_attributes["distance"]] # Conseguimos el atributo deseado y lo guardamos en la lista
        
        # Ordenamos las aristas de menor a mayor distancia. Para ello comprobamos cual es la que tiene menor valor y aniadimos el final a la lista
        distances = np.array(distances) # Convertimos a un array numpy
        tidy_edges = [] # Aristas ordenadas por coste de menor a mayor
        max_value = distances.max() + 1 # Fijamos un numero maximo, de forma que cuando guardemos una arista. No vuelva a ser seleccionada
        for j in range(0,len(edges)):
            argmin = distances.argmin() # Seleccionamos la posicion del valor mas pequenio
            tidy_edges += [edges[argmin][1]] # Seleccionamos la arista con argmin y luego seleccionamos el nodo final de la arista
            distances[argmin] = max_value
            
            
        # Aniadimos la lista al nodo
        g.nodes[nodes_list[i]]["nearest"] = tidy_edges
            
    return g

# %%
def normalize_data(data,max_value):
    """
    Normaliza una lista de numero entre 0 y el numero facilitado por parametro
    
    Parametros
        data : list
            Lista de numeros
        max_value : int
            Numero maximo que tendra la lista de valores normalizados
    
    Return 
        Devuelve la lista normalizada
    """
    return ((data - np.min(data)) / (np.max(data) - np.min(data))) * max_value

# %%
def normalize_x(x, max_value, min_value):
    """
    Normaliza un valor entre dos valores
    
    Parametros
        x : float
            Valor a normalizar
        max_value : float
            Valor de rango maximo
        min_value : float
            Valor de rango minimo
        
    Return valor normalizado
    """
    return (x - min_value) / (max_value - min_value)

# %% [markdown]
# ## Dibujar por pantalla

# %%
def draw_route(g, route, cost):
    """
    Muestra por pantalla la ruta en el grafo
    
    Parametros
        g : networkx
            Grafo de hormigas
        route : str list
            Lista con los nombres de los nodos recorridos
        cost : int
            Coste de la ruta recorrida
    """
    
    # OBTENEMOS TODAS LAS COORDENADAS
    nodes_list = list(g.nodes)
    x = [] # Lista de coordenadas x
    y = [] # Lista de coordenadas y
    for node in nodes_list:
        coord = g.nodes[node]['coord'] # Seleccionamos las coordenadas de un nodo
        x += [coord[0]] # Coord 0 es la coordenada x
        y += [coord[1]] # Coord 1 es la coordenada y
        
    plt.figure(figsize=(14, 8))
    plt.title(f"Coste del camino: {cost}")
    
    plt.plot(x,y,"blue") # Dibujamos la linea continua que une los puntos
    plt.scatter(x,y, c = "black") # Dibujamos todos los puntos
    plt.scatter(x[0],y[0],c="green") # Resaltamos el nodo inicial
    plt.scatter(x[-1],y[-1],c="red") # Resaltamos el nodo final
    
    plt.legend(["Ruta","Ciudades","Ciudad inicial","Ciudad final"])
    
    plt.show()

# %%
def draw_route_steps(g, route):
    """
    Muestra por pantalla la ruta en el grafo paso por paso
    
    Parametros
        g : networkx
            Grafo de hormigas
        route : str list
            Lista con los nombres de los nodos recorridos
        
    """
    fig = plt.figure(figsize=(14,8))
    ax = fig.add_subplot(1, 1, 1) 
    ax.set_facecolor('white')
    
    # OBTENEMOS TODAS LAS COORDENADAS
    nodes_list = list(g.nodes)
    x = [] # Lista de coordenadas x
    y = [] # Lista de coordenadas y
    for node in nodes_list:
        coord = g.nodes[node]['coord'] # Seleccionamos las coordenadas de un nodo
        x += [coord[0]] # Coord 0 es la coordenada x
        y += [coord[1]] # Coord 1 es la coordenada y
    
    
    # Dibujamos todos los puntos
    ax.scatter(x,y, c = "black") # Dibujamos todos los puntos
    ax.scatter(x[0],y[0],c="green") # Resaltamos el nodo inicial

    for i in range(2, len(route)+1): # Empezamos en 2 para que en la primera vez represente el primer paso        
        # Dibujamos la ruta
        if i !=2 :
            xs = x[i-3:i-1] 
            ys = y[i-3:i-1]
            ax.plot(xs,ys,c="blue") # Dibujamos la linea continua que une los puntos
        
        # Resaltamos el ultimo paso realizado
        ax.plot(x[i-2:i],y[i-2:i],c="red") # Dibujamos la linea continua que une los puntos
        
        # Reseteamos la pantalla
        display(fig)    
        clear_output(wait = True)
        plt.pause(0.0001)
    
    ax.plot(x[i-3:i-1],y[i-3:i-1],c="blue") 
    ax.plot(x[-2:],y[-2:],c="red")
    ax.scatter(x[-1],y[-1],c="red") # Resaltamos el nodo final
    display(fig)  
'''
g = nx.read_gpickle("./build_graph/graph_ch130.gpickle")
route, route_cost = greedy(g)
draw_route_steps(g, route)
'''
# Out:
# '\ng = nx.read_gpickle("./build_graph/graph_ch130.gpickle")\nroute, route_cost = greedy(g)\ndraw_route_steps(g, route)\n'

# %%
def draw_pheromones(g):
    """
    """
    fig = plt.figure(figsize=(16,10))
    ax = fig.add_subplot(1, 1, 1) 
    ax.set_facecolor('white')
    
    # OBTENEMOS TODAS LAS COORDENADAS
    nodes_list = list(g.nodes)
    x = [] # Lista de coordenadas x
    y = [] # Lista de coordenadas y
    for node in nodes_list:
        coord = g.nodes[node]['coord'] # Seleccionamos las coordenadas de un nodo
        x += [coord[0]] # Coord 0 es la coordenada x
        y += [coord[1]] # Coord 1 es la coordenada y
    
    
    # Dibujamos todos los puntos
    ax.scatter(x,y, c = "black") # Dibujamos todos los puntos
    ax.scatter(x[0],y[0],c="green") # Resaltamos el nodo inicial
    
    pheromones = np.array([])
    pheromones_norm = np.array([])
    draw_edges = 0
    start = time.time()
    for edge in g.edges:
        xe = []
        ye = []
        p = g.edges[edge]['pheromone']
        pheromones = np.append(pheromones, p)
        pheromones_norm = np.append(pheromones_norm, 1000000*p)
        #if pheromones_norm[-1] >= np.mean(pheromones_norm):
        xe += [g.nodes[edge[0]]['coord'][0]]
        xe += [g.nodes[edge[1]]['coord'][0]]
        ye += [g.nodes[edge[0]]['coord'][1]]
        ye += [g.nodes[edge[1]]['coord'][1]]
        ax.plot(xe,ye,c="blue", linewidth=6000*pheromones[-1])
        draw_edges += 1
    total_time = time.time()-start
    print(f"Tiempo: {total_time/60} min")
    ax.set_title(f"Mapa de feromonas - Aristas representadas {draw_edges}/{g.number_of_edges()}")

# %%
def draw_pheromones_by_node(g, density):
    """
    """
    # COMPROBAMOS QUE DENSITY NO SUPERE EL NUMERO MAXIMO DE NODOS
    if density > g.number_of_nodes():
        density = g.number_of_nodes()
    
    fig = plt.figure(figsize=(18,12))
    ax = fig.add_subplot(1, 1, 1) 
    ax.set_facecolor('white')
    
    # OBTENEMOS TODAS LAS COORDENADAS
    nodes_list = list(g.nodes)
    x = [] # Lista de coordenadas x
    y = [] # Lista de coordenadas y
    for node in nodes_list:
        coord = g.nodes[node]['coord'] # Seleccionamos las coordenadas de un nodo
        x += [coord[0]] # Coord 0 es la coordenada x
        y += [coord[1]] # Coord 1 es la coordenada y
    
    
    # Dibujamos todos los puntos
    dots_size = 100
    ax.scatter(x,y, c = "black",s=dots_size) # Dibujamos todos los puntos
    ax.scatter(x[0],y[0],c="green",s=dots_size) # Resaltamos el nodo inicial
    
    # Calculamos la media de pheromonas
    pheromones_list = []
    proportion = 1000000
    for node in g.nodes:
        nearest = g.nodes[node]["nearest"]
        for i in range(0, density):
            pheromones_list += [g.edges[(node,nearest[i])]['pheromone']]
    pheromones_list = np.array(pheromones_list)
    
    min_value = pheromones_list.min()
    max_value = pheromones_list.max()
    
    start = time.time()
    line_upscale = 100000
    max_thickness = 5
    min_thickness = 0.1
    draw_edges = 0
    edges_over_mean = 0
    edges_under_mean = 0
    c_over_mean = "blue"
    c_under_mean = "red"
    for node in g.nodes:
        nearest = g.nodes[node]["nearest"]
        for i in range(0, density):
            xe = []
            ye = []
            p = g.edges[(node,nearest[i])]['pheromone']
            xe += [g.nodes[node]['coord'][0]]
            xe += [g.nodes[nearest[i]]['coord'][0]]
            ye += [g.nodes[node]['coord'][1]]
            ye += [g.nodes[nearest[i]]['coord'][1]]
            
            '''
            line_thickness = normalize_x(p,max_value,min_value) * max_thickness
            if line_thickness < min_thickness:
                line_thickness = min_thickness
            '''
            
            if p > pheromones_list.mean():
                
                line_thickness = normalize_x(p, max_value, pheromones_list.mean()) * max_thickness
                if line_thickness < min_thickness:
                    line_thickness = min_thickness + 0.5
                ax.plot(xe,ye,c=c_over_mean, linewidth=line_thickness)
                edges_over_mean += 1
            else:
                line_thickness = normalize_x(p, pheromones_list.mean(), min_value) * max_thickness
                if line_thickness < min_thickness:
                    line_thickness = min_thickness
                ax.plot(xe,ye,c=c_under_mean, linewidth=line_thickness)
                edges_under_mean += 1
            draw_edges += 1
    total_time = time.time()-start
    print(f"Tiempo: {total_time/60} min")
    ax.set_title(f"Mapa de feromonas - Aristas representadas: {draw_edges}/{g.number_of_edges()} - Over mean({c_over_mean}): {edges_over_mean}/{draw_edges} - Under mean({c_under_mean}): {edges_under_mean}/{draw_edges}")

# %%
def draw_ant_fitness(ant_cost_list):
    """
    """
    x = []
    y = ant_cost_list
    legend = []

    x = np.arange(len(y))

    # PLOT
    ax = plt.figure()
    ax.set_facecolor('white')

    plt.plot(x,y)

    #plt.title("Alpha study")
    plt.xlabel("Iterations")
    plt.ylabel("Km")
    plt.legend(legend)
    # Si queremos que la leyenda este a la derecha
    '''
    plt.subplots_adjust(right=0.7)
    plt.legend(legend, bbox_to_anchor=(1.04,0.5), loc="center left")
    '''
    plt.grid(axis='both',linestyle='solid', color='k', zorder=0)
    plt.savefig('./study/basic_genetic/population'+str(sizes[0])+'_generations.png', dpi=100)
    plt.show()

# %%
#draw_pheromones_by_node(g,15)

# %% [markdown]
# ## Construcción de grafos - Estructuras para ch130 y a280

# %%
def graph_construction():
    """
    Construye los grafos para los archivos .tsp: ch130 y a280. Una vez creados se almacenan en la 
    carpeta './build_graph'        
    """
    m = tsp_to_matrix("./tsp/ch130.tsp") # Cargamos los datos
    g = create_sh_graph(m) # Creamos le grafo
    nx.write_gpickle(g, "./build_graph/graph_ch130.gpickle") # Guardamos el grafo

    m = tsp_to_matrix("./tsp/a280.tsp") # Cargamos los datos
    g = create_sh_graph(m) # Creamos le grafo
    nx.write_gpickle(g, "./build_graph/graph_a280.gpickle") # Guardamos el grafo

graph_construction()
#g_ch130 = nx.read_gpickle("./build_graph/graph_ch130.gpickle")
#g_a280 = nx.read_gpickle("./build_graph/graph_a280.gpickle")

# %% [markdown]
# ## Clase Hormiga

# %%
class ant:
    '''
    Contiene los atributos de una hormiga
    '''
    def __init__(self):
        '''
        Inicializador de  la clase
        '''
        self.route = [] # Lista de nodos por el que ha pasado la hormiga
        self.not_visited = [] # Lista de nodos no visitados por la hormiga
        self.edge_route = [] # Lista de aristas recorridas
        self.cost = 0 # Coste de la ruta seguida por la hormiga
        
    def reset(self):
        '''
        Vuelve a inicializar todos sus atributos
        '''
        self.route = [] # Lista de nodos por el que ha pasado la hormiga
        self.not_visited = [] # Lista de nodos no visitados por la hormiga
        self.edge_route = [] # Lista de aristas recorridas
        self.cost = 0 # Coste de la ruta seguida por la hormiga

# %% [markdown]
# # Algoritmos

# %% [markdown]
# ## Greedy

# %% [markdown]
# ### Teoría

# %% [markdown]
# Para generar la solución greedy recorreremos el grafo seleccionando el nodo más cercano al actual que no se haya seleccionado previamente

# %% [markdown]
# ### Codigo

# %%
def greedy(g):
    """
    Calcula la solucion greedy del grafo. Para ello seleccionara la ciudad al nodo actual hasta recorrer todos los nodos
    
    Parametros
        g : networkx
            Grafo de hormigas
            
    Return
        Devuelve una lista de dos posiciones. [ruta_encontrada, coste_de_la_ruta]
    """
    
    # INICIALIZAMOS LOS PARAMETROS
    route = [] # Ruta greedy
    cost = 0 # Coste greedy
    
    # Establecemos el primer nodo
    nodes_list = list(g.nodes()) # Cogemos la lista de nodos
    init_node = nodes_list[0] # Seleccionamos el primero
    route += [init_node] # Lo aniadimos a la ruta
    
    # CALCULAMOS LA RUTA GREEDY
    gr, cost = greedy_route(g, route, cost) # Greedy route
    
    return gr, cost

# %% [markdown]
# #### Métodos auxiliares

# %%
def greedy_route(g, route, cost):
    """
    Calcula de forma recursiva el camino mas rapido del grafo
    
    Parametros
        g : networkx
            Grafo de hormigas
        route : list
            Lista vacia donde ir guardando la ruta
        cost : int
            Variable iniciada a 0 donde ir guardando el coste 
    
    Return
        Devuelve una lista de dos posiciones. [ruta_encontrada, coste_de_la_ruta]
    """
    # IMPLEMENTAMOS UN ALGORITMO RECURSIVO, PARAMOS CUANDO LA RUTA TENGA EL MISMO NUMERO DE ELEMNTOS QUE EL GRAFO FINALICE
    if len(route) < g.number_of_nodes():
        # BUSCAMOS EL NODO MAS CERCANO AL ULTIMO NODO DE LA RUTA
        actual_node = route[-1] # Seleccionamos el ultimo nodo - Nodo actual

        # Obtenemos la lista de las ciudades mas cercanas a nuestro nodo actual
        nearest = g.nodes[actual_node]["nearest"]
        
        # Recorremos la lista de nodos cercanos y seleccionamos el primero que no haya sido seleccionado previamente
        for next_node in nearest:
            if (next_node in route) == False: # Si el siguiente nodo no esta la ruta lo agregamos
                route += [next_node] 
                edge_attributes = g.get_edge_data(actual_node, next_node) # Devuelve un diccionario con los atributos de la arista
                cost += edge_attributes["distance"]
                #print(f"({actual_node},{next_node}){edge_attributes}")
                break # Salimos del bucle
                
        # VOLVEMOS A LLAMAR A LA FUNCION
        return greedy_route(g, route, cost)
    else:
        return route, round(cost,3)

# %% [markdown]
# ## Sistema de Hormigas (SH)

# %% [markdown]
# ### Teoría

# %% [markdown]
# Las hormigas naturales son capaces de resolver problemas de camino mínimo como el TSP. Los algoritmos de OCH reproducen el compartamiento de las hormigas reales en una colonia artificial de hormigas para resolver problemas complejos de camino mínimo.
#
# Cada hormiga _artificial_ es un mecanismoprobabilístico de construcción de soluciones al problema que utiliza:
# * **Unos rastros de feromonas(_artificiales_), τ(tau)** que cambian con el tiempo para reflejar la experienca adquirida por los agentes en la resolución del problema
# * **Información heurística η(eta)** sobre la instancia concreta del problema
#
#      ![title](img/Hormigas_graph.png)
#
# La **hormiga artificial** es un agente que:
# * Recuerda los nodos que ha recorrido, utilizando para ello una lista de nodos visitados (**L**). Al finalizar, esta lista contiene la solución construida por la hormiga
# * En cada paso, estando en la ciudad _r_ elige hacia qué ciudad _s_ moverse de entre las vecinas de _r_ que no hayan sido visitados aun, según una **regla probabilística de transición**
# * La decición tomada por esta _regla_ depende de la preferencia heurística η_rs = 1/d_rs y la feromona τ_rs
#
#  ![title](img/Regla_probabilistica_de_transicion.png)
#
# **Actualización de feromona**
# 1. **APORTE**: Se usa una retroalimentación positiva para reforzar en el futuro los componentes de la buenas soluciones mediante un aporte adicional de feromona. **Cuanto mejor sea la solución, más feromona se aporta**
# 2. **EVAPORACIÓN**: Se usa la evaporación de feromona para evitar un incremento ilimitado de los rastros de feromona y para permitir olvidar las malas decisiones tomadas
#
# La evaporación es la misma para todos los rastros, eliminándose un porcentaje de su valor actual, según un parámetro de evaporación ρ(ro), el cual toma valor en el intervalo: 0≤ρ≤1
#
# Es un mecanismo de evaporación más activo que la natural, lo que evita la perduración de los rastros de feromon y, por tanto, el estancamiento de óptimos locales.
#
#    ![title](img/Regla_actualizacion_feromona.png)
#
# **Algoritmo**
#
#    ![title](img/sh_1.png)
#    ![title](img/sh_2.png)

# %% [markdown]
# ### Codigo

# %%
def sh(seed, g, n, m, alpha, beta, ro, display):
    """
    Calcula el camino del grafo usando un algoritmo de hormigas
    
    Parametros
        seed : int 
            Semilla con la que generar numeros aleatorios
        g : networkx
            Grafo creado con el metodo: create_sh_graph(m)
        n : int
            Numero de ejecuciones a realizar
        m : int
            Numero de hormigas
        alpha : float
            Valor que establece la importania de la informacion memoristica en la regla probabilistica de transicion 
        beta : float 
            Valor que establece la importancia de la información heristica en la regla probabilistica de transicion 
        ro : float
            Valor del parametro de evaporacion en la actualizacoin de feromona (0<ro<1)
        display : bool
            Si es igual a 'True' mostrara por pantalla todas las soluciones que vaya encontrando ademas de una comparativa final entre la primer y la ultima solucion encontrada. Dejar a 'False' para no mostrar nada
    Return
        Devuelve una lista de tres posiciones: [best_actual_route, best_actual_cost, ev]
    """
    
    # CALCULAMOS EL VALOR DE FEROMONAS INICIAL Y LO ESTABLECEMOS
    gr, gr_cost =  greedy(g) # Para ello necesitamos calcular el coste de la solucion greedy
    tau_init = 1 / (g.number_of_nodes() * gr_cost) # Formula: init_pheromone = 1 / (number of nodes * cost of greedy solution)
    init_pheromones(g, tau_init) # Inicializa las feromonas de cada arista
    
    if display == True:
        print(f"Init SH solution: {gr_cost} km")
    
    # INICIALIZAMOS LOS PARAMETROS
    np.random.seed(seed) # Inicializamos la semilla
    ev = 0 # Numero de evaluaciones realizadas
    t = 0 # Variable que usaremos para actualizar el tiempo que llevamos buscando una solucion
    time_start = time.time()
    max_time = 300 # 300s = 5 min
    
    # Creamos las hormigas
    ant_list = [] # Lista de hormigas
    for i in range(0,m):
        ant_list += [ant()]
        
    init_node = list(g.nodes)[0] # Nodo inicial
    
    best_ant = ant() # Me
    best_ant.route = gr.copy() # Mejor ruta encontrada
    best_ant.cost = gr_cost # Coste de la mejor ruta 
    
    cost_history = []
    
    # BUCLE DE ITERACIONES
    i = 0
    t = time.time() - time_start # Tiempo transcurrido desde time_start
    while i < 10000*n and t < max_time:
        if display == True:
            print(f"Iteracion {i}")
            
        # ASIGANAMOS EL NODO INICIAL PARA CADA HORMIGA
        for j in range(0,m):
            ant_list[j].reset() # Reseteamos todos los valores de la hormiga
            select = np.random.randint(0,g.number_of_nodes())
            node = list(g.nodes)[select]
            ant_list[j].route += [node] # Establecemos el nodo inicial
            nl = list(g.nodes).copy() # Copiamos todos los nodos
            nl.remove(node) # Eliminamos el nodo inicial
            ant_list[j].not_visited += nl
            
            
        # CADA HORMIGA ENCUENTRA UNA SOLUCION
        C = ants_find_route(g, ant_list, alpha, beta) # Devuelve la matriz de rutas actualizada
        
        # ESCOGEMOS LA MEJOR SOLUCION ENCONTRADA
        index = C.index(min(C)) # Seleccionamos la ruta que tenga menor coste
        best_actual_ant = ant_list[index] # Seleccionamos la mejor hormiga encontrada
        cost_history += [best_actual_ant.cost]
        
        # Pintamos el coste de cada hormiga
        '''
        if display == True:
            for j in range(0,len(ant_list)):
                print(f"Ant({j}): {ant_list[j].cost}", end=' ')
            print('')
        '''   
        # ACTUALIZAMOS LAS FEROMONAS
        update_pheromones(g, ant_list, ro, 0, best_ant) # 0 Porque no al ser sh no tenemos ninguna hormiga elitista
        
        # COMPROBAMOS SI LA SOLUCION ACTUAL ES MEJOR QUE LA MEJOR ENCONTRADA HASTA EL MOMENTO
        if best_actual_ant.cost < best_ant.cost:
            best_ant.cost = best_actual_ant.cost
            best_ant.route = best_actual_ant.route.copy()
            
            if display == True:
                print(f"New SH best solution: {best_ant.cost} km")
            
        i += 1
        t = time.time() - time_start
    return best_ant.route.copy(), best_ant.cost, ev, cost_history

# %% [markdown]
# #### Métodos auxiliares

# %%
def init_pheromones(g, init_pheromone):
    """
    Inicializa el parametro 'pheromone' de todas las aristas del grafo
    
    Parametros
        g : networkx
            Grafo de hormigas
        init_pheromone : float
            Valor de feromonas inicial
    """
    for edge in g.edges: # edge es una tupla con el nombre de cada nodo que forma la arista
        g.edges[edge[0],edge[1]]['pheromone'] = init_pheromone

# %%
def ants_find_route(g, ant_list, alpha, beta):
    """
    Calcula de forma recursiva el recorrido de una o varias hormigas por el grafo. Las rutas calculadas y los costes se almacenara en cada hormiga
    
    Parametros
        g : networkx
            Grafo de hormigas
        ant_list : list of ant
            Lista de hormigas que recorreran el grafo
        alpha : float
            Valor que establece la importania de la informacion memoristica en la regla probabilistica de transicion 
        beta : float 
            Valor que establece la importancia de la información heristica en la regla probabilistica de transicion 
    Return
        Devuelve una lista con los costes encontrados por cada hormiga
    """
    if len(ant_list[0].route) < g.number_of_nodes():
        # Calculamos el camino a seguir por cada hormiga
        for i in range(0,len(ant_list)):
            actual_node = ant_list[i].route[-1] # Cogemos el ultimo nodo visitado para la hormiga i
            
            ant_list[i].route += [transition_rule(g, actual_node, ant_list[i].not_visited, alpha, beta)] # Aniadimos el nuevo nodo alcanzado
            ant_list[i].not_visited.remove(ant_list[i].route[-1]) # Eliminamos el nodo que acabamos de meter en L[i]
            
            ant_list[i].edge_route += [(ant_list[i].route[-2], ant_list[i].route[-1])] # Aniadimos la arista. tupla(node_start, node_end)
            ant_list[i].cost += g.edges[ant_list[i].route[-2], ant_list[i].route[-1]]['distance'] # Actualizamos el coste del camino de la hormiga i. Para ello seleccionamos los 2 ultimos nodos aniadidos a la ruta
            #print(f"Ant({i}): {ant_list[i].cost}", end=', ')
        #print('')
        return ants_find_route(g, ant_list, alpha, beta)
    else:
        # Hacemos una lista del coste que ha tenido cada hormiga
        c = [] # Lista con el coste de cada hormiga
        for i in range(0,len(ant_list)):
            c += [ant_list[i].cost]
            
        return c

# %%
def transition_rule(g, actual_node, not_visited, alpha, beta):
    """
    Calcula el nodo siguiente de la hormiga
    
    Parametros
        g : networkx
            Grafo de hormigas
        actual_node : str
            Nodo en el que se encuentra la hormmiga
        not_visited : list
            Lista de nodos que la hormiga no ha visitado(sus nombres)
        alpha : float
            Valor que establece la importania de la informacion memoristica en la regla probabilistica de transicion 
        beta : float 
            Valor que establece la importancia de la información heristica en la regla probabilistica de transicion 
    Return
        Devuelve el nombre del siguiente nodo a visitar por la hormiga
    """
    
    '''
    La regla de transicion nos cual es el siguiente nodo a seguir. Para ello emplearemos
    la siguiente formula
    
    La probabilidad de ir desde r hasta s es igual a:
    probabilidad(r,s) = (tau_rs**alpha * eta_rs**beta) / (sum(tau_ru)**alpha * eta_ru**beta)
    
    - tau_rs es la cantidad de feromonas de la arista entre r y s
    - eta_rs cantidad de inf. heuristica de la arista entre r y s
    - tau_ru cantidad de feromonas para cada una de las aristas alcanzables desde r
    - eta_ru cantidad de inf. heuristica para cada una de las aristas alcanzables desde r
    
    Una vez calculado todas las probabilidades elegimos la que tiene mayor probabilidad
    '''
    p = [] # Probabilidad de cada arista
    tau = [] # Feromona de cada arista
    eta = [] # Heuristica de cada arista
    
    # OBTENEMOS LOS ATRIBUTOS DE CADA ARISTA
    for i in range(0,len(not_visited)):
        edge = g.edges[actual_node, not_visited[i]] # Arista
        tau += [edge['pheromone']] # Obtenemos la feromona
        eta += [edge['heuristic']] # Obtenemos la heuristica
        
    # Convertimos a un numpy array para facilitar los calculos
    tau_list = np.array(tau)
    eta_list = np.array(eta)
    
    # CALCULAMOS LA PROBABILIDAD DE CADA ARISTA
    addition = sum(tau_list**alpha * eta_list**beta)  # sumatorio
    for i in range(0,len(not_visited)):
        # Formula explicada arriba
        p += [(tau[i]**alpha * eta[i]**beta) / addition]
    
    # SELECCIONAMOS LA ARISTA CON MEJOR PROBABILIDAD
    index = p.index(max(p)) # Buscamos el index en la lista de probabilidad, eso nos dara el nodo no visitado a seleccionar
    
    return not_visited[index]

# %%
def update_pheromones(g, ant_list, ro, elite, best_ant):
    """
    Actualizas las feromonas de todas las aristas del grafo. Los cambios son almacenados en el grafo
    
    Parametros
        g : networkx
            Grafo de hormigas
        ant_list : list of ant
            Lista de hormigas
        ro : float
            Valor del parametro de evaporacion en la actualizacoin de feromona (0<ro<1)
        elite : int
            Numero de hormigas elite. En caso de no haber, su valor es igual a 0
        best_ant : ant
            Hormiga que ha encontrado el mejor camino hasta el momento
    """
    '''
    Formula de actualizacion de feromonas para SH:
    
        new_tau = (1 - ro)*actual_tau + sum_1_to_m(1/cost(route_k))
    
    Formula de actualizacion de feromonas para SHE:
    
        new_tau = (1 - ro)*actual_tau + sum_1_to_m(1/cost(route_k)) + elite*(1/coste(best_route))
    '''

    # ACTUALIZAMOS LAS PHEROMONAS DE TODAS LAS ARISTAS
    for edge in g.edges:
        # Calculamos primero el termino de aporte, para ello vemos que si nuestras hormigas han pasado por esta arista
        addition = 0 # Sumatorio de aporte
        for ant in ant_list:
            if edge in ant.edge_route: # Si la arista seleccionada esta en la ruta de la hormiga
                addition += (1 / ant.cost) # Sumamos: 1 / coste_de_la_arista
            if elite > 0:
                if edge in best_ant.route:
                    addition += elite*(1 / best_ant.cost)
        g.edges[edge]['pheromone'] = (1 - ro) * g.edges[edge]['pheromone'] + addition

# %% [markdown]
# ## Sistema de Hormigas Elitistas (SHE)

# %% [markdown]
# ### Teoría

# %% [markdown]
# La única diferencia entre SHE y SH es la regla de actualización que aplica un refuerzo adicional de los buenos arcos(aristas)
#
# ![title](img/Regla_actualizacion_feromona_she.png)
#
# Donde __e__ es el número de hormigas elitistas consideradas y __mejor_global__ es la mejor solución obtenida hasta el momento

# %% [markdown]
# ### Código

# %%
def she(seed, g, n, m, alpha, beta, ro, elite, display):
    """
    Calcula el camino del grafo usando un algoritmo de hormigas elitistas
    
    Parametros
        seed : int 
            Semilla con la que generar numeros aleatorios
        g : networkx
            Grafo creado con el metodo: create_sh_graph(m)
        n : int
            Numero de ejecuciones a realizar
        m : int
            Numero de hormigas
        alpha : float
            Valor que establece la importania de la informacion memoristica en la regla probabilistica de transicion 
        beta : float 
            Valor que establece la importancia de la información heristica en la regla probabilistica de transicion 
        ro : float
            Valor del parametro de evaporacion en la actualizacoin de feromona (0<ro<1)
        elite : int
            Numero de hormigas elitistas
        display : bool
            Si es igual a 'True' mostrara por pantalla todas las soluciones que vaya encontrando ademas de una comparativa final entre la primer y la ultima solucion encontrada. Dejar a 'False' para no mostrar nada
    Return
        Devuelve una lista de tres posiciones: [best_actual_route, best_actual_cost, ev]
    """
    
    # CALCULAMOS EL VALOR DE FEROMONAS INICIAL Y LO ESTABLECEMOS
    gr, gr_cost =  greedy(g) # Para ello necesitamos calcular el coste de la solucion greedy
    init_tau = 1 / (g.number_of_nodes() * gr_cost) # Formula: init_pheromone = 1 / (number of nodes * cost of greedy solution)
    init_pheromones(g, init_tau) # Inicializa las feromonas de cada arista
    
    if display == True:
        print(f"Init SHE solution: {gr_cost} km")
    
    # INICIALIZAMOS LOS PARAMETROS
    np.random.seed(seed) # Inicializamos la semilla
    ev = 0 # Numero de evaluaciones realizadas
    t = 0 # Variable que usaremos para actualizar el tiempo que llevamos buscando una solucion
    time_start = time.time()
    max_time = 300 # 300s = 5 min
    
    # Creamos las hormigas
    ant_list = [] # Lista de hormigas
    for i in range(0,m):
        ant_list += [ant()]
        
    init_node = list(g.nodes)[0] # Nodo inicial
    
    best_ant = ant() # Me
    best_ant.route = gr.copy() # Mejor ruta encontrada
    best_ant.cost = gr_cost # Coste de la mejor ruta 
    
    cost_history = []
    
    # BUCLE DE ITERACIONES
    i = 0
    t = time.time() - time_start # Tiempo transcurrido desde time_start
    while i < 10000*n and t < max_time:
        print(f"Iteracion {i}")
        # ASIGANAMOS EL NODO INICIAL PARA CADA HORMIGA
        for j in range(0,m):
            ant_list[j].reset() # Reseteamos todos los valores de la hormiga
            ant_list[j].route += [init_node] # Establecemos el nodo inicial
            ant_list[j].not_visited += list(g.nodes)[1:] # Cogemos todos los nodos menos el primero
            
        # CADA HORMIGA ENCUENTRA UNA SOLUCION
        C = ants_find_route(g, ant_list, alpha, beta) # Devuelve la matriz de rutas actualizada
        
        # ESCOGEMOS LA MEJOR SOLUCION ENCONTRADA
        
        index = C.index(min(C)) # Seleccionamos la ruta que tenga menor coste
        best_actual_ant = ant_list[index] # Seleccionamos la mejor hormiga encontrada
        cost_history += [best_actual_ant.cost]
        
        # ACTUALIZAMOS LAS FEROMONAS
        update_pheromones(g, ant_list, ro, elite, best_ant) # 0 Porque no al ser sh no tenemos ninguna hormiga elitista
        
        # COMPROBAMOS SI LA SOLUCION ACTUAL ES MEJOR QUE LA MEJOR ENCONTRADA HASTA EL MOMENTO
        if best_actual_ant.cost < best_ant.cost:
            best_ant.cost = best_actual_ant.cost
            best_ant.route = best_actual_ant.route.copy()
            
            if display == True:
                print(f"New SHE best solution: {best_actual_cost} km")
            
        i += 1
        t = time.time() - time_start
    return best_ant.route.copy(), best_ant.cost, ev, cost_history

# %% [markdown]
# ## Sistema de Colonia de Hormigas (SCH)

# %% [markdown]
# ### Teoría

# %% [markdown]
# El Sistema de Colonia de Hormigas extiende a su predesor, el SH, en **tres** aspecctos:
# - La **regla probabilística de transición** establece un equilibrio entre la exploración de nuevos arcos y la explotación de la información acumulada
# - Para la **actualizción (global) de feromona** solo se considera la hormiga que generó la mejor solución hasta ahora, y solo se evapora feromona en los arcos que componen ésta
# - Se añade una nueva actualización (local) de feroona basada en que cada hormiga modifica automáticamente la feromona de cada arco que visita para diversificar la búsqueda
#
# ![title](img/Regla_probabilistica_de_transicion_sch.png)
#
# ![title](img/Regla_actualizacion_feromona_global_sch.png)
#
# ![title](img/Regla_actualizacion_feromona_local_sch.png)
#
# En la regla de actualización local:
# * φ(fi) = 0.1
#
# **Pseudocódigo**
#
# ![title](img/sch_1.png)
# ![title](img/sch_2.png)

# %% [markdown]
# ### Código

# %%
def sch(seed, g, n, m, alpha, beta, ro, q0, fi, display):
    """
    Calcula el camino del grafo usando un algoritmo de sistema de colonias de hormigas
    
    Parametros
        seed : int 
            Semilla con la que generar numeros aleatorios
        g : networkx
            Grafo creado con el metodo: create_sh_graph(m)
        n : int
            Numero de ejecuciones a realizar
        m : int
            Numero de hormigas
        alpha : float
            Valor que establece la importania de la informacion memoristica en la regla probabilistica de transicion 
        beta : float 
            Valor que establece la importancia de la información heristica en la regla probabilistica de transicion 
        ro : float
            Valor del parametro de evaporacion en la actualizacion de feromona (0<ro<1)
        q0 : float
            Probabilidad de seleccionar una transicion SCH o una SH
        fi : float
            Valor entre 0 y 1
        display : bool
            Si es igual a 'True' mostrara por pantalla todas las soluciones que vaya encontrando ademas de una comparativa final entre la primer y la ultima solucion encontrada. Dejar a 'False' para no mostrar nada
    Return
        Devuelve una lista de tres posiciones: [best_actual_route, best_actual_cost, ev]
    """
    
    # CALCULAMOS EL VALOR DE FEROMONAS INICIAL Y LO ESTABLECEMOS
    gr, gr_cost =  greedy(g) # Para ello necesitamos calcular el coste de la solucion greedy
    init_tau = 1 / (g.number_of_nodes() * gr_cost) # Formula: init_pheromone = 1 / (number of nodes * cost of greedy solution)
    init_pheromones(g, init_tau) # Inicializa las feromonas de cada arista
    
    if display == True:
        print(f"Init SCH solution: {gr_cost} km")
    
    # INICIALIZAMOS LOS PARAMETROS
    np.random.seed(seed) # Inicializamos la semilla
    ev = 0 # Numero de evaluaciones realizadas
    t = 0 # Variable que usaremos para actualizar el tiempo que llevamos buscando una solucion
    time_start = time.time()
    max_time = 300 # 300s = 5 min
    
    # Creamos las hormigas
    ant_list = [] # Lista de hormigas
    for i in range(0,m):
        ant_list += [ant()]
        
    init_node = list(g.nodes)[0] # Nodo inicial
    
    best_ant = ant() # Me
    best_ant.route = gr.copy() # Mejor ruta encontrada
    best_ant.cost = gr_cost # Coste de la mejor ruta 
    
    cost_history = []
    
    # BUCLE DE ITERACIONES
    i = 0
    t = time.time() - time_start # Tiempo transcurrido desde time_start
    while i < 10000*n and t < max_time:
        # ASIGANAMOS EL NODO INICIAL PARA CADA HORMIGA
        for j in range(0,m):
            ant_list[j].reset() # Reseteamos todos los valores de la hormiga
            ant_list[j].route += [init_node] # Establecemos el nodo inicial
            ant_list[j].not_visited += list(g.nodes)[1:] # Cogemos todos los nodos menos el primero
            
        # CADA HORMIGA ENCUENTRA UNA SOLUCION
        C = ants_find_route_sch(g, ant_list, alpha, beta, q0, fi, init_tau) # Devuelve la matriz de rutas actualizada
        
        # ESCOGEMOS LA MEJOR SOLUCION ENCONTRADA
        index = C.index(min(C)) # Seleccionamos la ruta que tenga menor coste
        best_actual_ant = ant_list[index] # Seleccionamos la mejor hormiga encontrada
        cost_history += [best_actual_ant.cost]
        
        if display == True:
            print(f"Iteracion {i} - Best actual ant cost: {best_actual_ant.cost}")
            
        # COMPROBAMOS SI LA SOLUCION ACTUAL ES MEJOR QUE LA MEJOR ENCONTRADA HASTA EL MOMENTO
        if best_actual_ant.cost < best_ant.cost:
            best_ant.cost = best_actual_ant.cost
            best_ant.route = best_actual_ant.route.copy()
            
            if display == True:
                print(f"New SCH best solution: {best_actual_cost} km")
            
        # ACTUALIZAMOS LAS FEROMONAS DE FORMA GLOBAL
        update_global_pheromones(g, best_ant, ro)
        
        i += 1
        t = time.time() - time_start
    return best_ant.route.copy(), best_ant.cost, ev, cost_history

# %% [markdown]
# #### Métodos auxiliares

# %%
def transition_rule_shc(g, actual_node, not_visited, alpha, beta, q0):
    """
    Calcula el nodo siguiente de la hormiga mediante la regla de transicion SCH
    
    Parametros
        g : networkx
            Grafo de hormigas
        actual_node : str
            Nodo en el que se encuentra la hormmiga
        not_visited : list
            Lista de nodos que la hormiga no ha visitado(sus nombres)
        alpha : float
            Valor que establece la importania de la informacion memoristica en la regla probabilistica de transicion 
        beta : float 
            Valor que establece la importancia de la información heristica en la regla probabilistica de transicion 
        q0 : float
            Probabilidad de que se realice la una transicion mediante el algoritmo SCH en lugar de una SH
    Return
        Devuelve el nombre del siguiente nodo a visitar por la hormiga
    """
    '''
    Para el algoritmo SCH realizaremos su regla de transicion cuando ro sea menor que init_ro.
    Donde ro sera un valor aleatorio(0,1). Si no se cumple, realizaremos la regla de transicion 
    del SH. La formala para el SCH es la siguiente
    
    La probabilidad de ir desde r hasta s es igual a:
    s = arg_max(tau_ru**alpha * eta_ru**beta) si q <= q0 | S en caso contrario
    
    - tau_ru cantidad de feromonas para cada una de las aristas alcanzables desde r
    - eta_ru cantidad de inf. heuristica para cada una de las aristas alcanzables desde r
    - S es una ciudad aleatoria seleccionada segun la regla de transicion SH
    
    Debemos comprobar para todas las aristas cual es la que tiene mayor argumento
    '''
    q = np.random.rand() # El metodo de transicion sera determinado por esta variable
    
    if q <= q0:
        # REGLA TRANSICION SCH
        arg_list = [] # Lista de argumentos para cada arista no visitada
        
        # OBTENEMOS LOS ATRIBUTOS DE CADA ARISTA
        for i in range(0,len(not_visited)):
            edge = g.edges[actual_node, not_visited[i]] # Arista
            tau = edge['pheromone'] # Obtenemos la feromona
            eta = edge['heuristic'] # Obtenemos la heuristica
            arg_list += [tau**alpha * eta**beta] # Aniadimos el argumento de la arista en la lista
            
        # SELECCIONAMOS LA ARISTA CON MEJOR PROBABILIDAD
        index = arg_list.index(max(arg_list)) # Buscamos el index en la lista de probabilidad, eso nos dara el nodo no visitado a seleccionar
        
        return not_visited[index]
    else:
        # REGLA DE TRANSICION SH
        return transition_rule(g, actual_node, not_visited, alpha, beta)

# %%
def ants_find_route_sch(g, ant_list, alpha, beta, q0, fi, init_tau):
    """
    Calcula de forma recursiva el recorrido de una o varias hormigas por el grafo. Las rutas calculadas y los costes se almacenara en cada hormiga
    
    Parametros
        g : networkx
            Grafo de hormigas
        ant_list : list of ant
            Lista de hormigas que recorreran el grafo
        alpha : float
            Valor que establece la importania de la informacion memoristica en la regla probabilistica de transicion 
        beta : float 
            Valor que establece la importancia de la información heristica en la regla probabilistica de transicion 
        q0 : float
            Probabilidad de que se realice la una transicion mediante el algoritmo SCH en lugar de una SH
        fi : float
            Valor entre 0 y 1
        init_tau : float
            Valor de feromonas inicial
    Return
        Devuelve una lista con los costes encontrados por cada hormiga
    """
    if len(ant_list[0].route) < g.number_of_nodes():
        # Calculamos el camino a seguir por cada hormiga
        for i in range(0,len(ant_list)):
            actual_node = ant_list[i].route[-1] # Cogemos el ultimo nodo visitado para la hormiga i
            
            ant_list[i].route += [transition_rule_shc(g, actual_node, ant_list[i].not_visited, alpha, beta, q0)] # Aniadimos el nuevo nodo alcanzado
            ant_list[i].not_visited.remove(ant_list[i].route[-1]) # Eliminamos el nodo que acabamos de meter en L[i]
            
            ant_list[i].edge_route += [(ant_list[i].route[-2], ant_list[i].route[-1])] # Aniadimos la arista. tupla(node_start, node_end)
            ant_list[i].cost += g.edges[ant_list[i].route[-2], ant_list[i].route[-1]]['distance'] # Actualizamos el coste del camino de la hormiga i. Para ello seleccionamos los 2 ultimos nodos aniadidos a la ruta
            
            # ACTUALIZAMOS LAS FEROMONAS DE FORMA LOCAL
            update_local_pheromones(g, ant_list[i], fi, init_tau)
            
        return ants_find_route(g, ant_list, alpha, beta)
    else:
        # Hacemos una lista del coste que ha tenido cada hormiga
        c = [] # Lista con el coste de cada hormiga
        for i in range(0,len(ant_list)):
            c += [ant_list[i].cost]
            
        return c

# %%
def update_local_pheromones(g, select_ant, fi, init_tau):
    """
    Actualizas las feromonas de la ultima arista que visito la hormiga
    
    Parametros
        g : networkx
            Grafo de hormigas
        select_ant : ant
            Lista de hormigas
        fi : float
            Valor entre 0 y 1
        init_tau : float
            Valor de feromonas inicial
    """
    '''
    Formula de actualizacion de feromonas local para SCH:
    
        new_tau = (1 - fi)*actual_tau + fi*init_tau
    '''

    # ACTUALIZAMOS LAS PHEROMONAS DE LA ULTIMA ARISTA VISITADA POR LA HORMIGA
    edge = select_ant.edge_route[-1]
    g.edges[edge]['pheromone'] = (1 - fi) * g.edges[edge]['pheromone'] + fi * init_tau

# %%
def update_global_pheromones(g, best_ant, ro):
    """
    Actualizacion global de feromonas. Actualiza las aristas pertenecientes a la mejor ruta encontrada
    hasta el momento.
    
    Parametros
        g : networkx
            Grafo de hormigas
        best_ant : ant
            Mejor hormiga hasta el momento
        ro : float
            Valor del parametro de evaporacion en la actualizacion de feromona (0<ro<1)
    """
    '''
    Formula de actualizacion de feromonas global para SCH:
    
        new_tau = (1 - ro)*actual_tau + ro*(1 / cost(best_solution))
    
    Solo se aplica a los arcos de la mejor ruta encontrada hasta el momento
    '''
    # ACTUALIZAMOS LAS PHEROMONAS DEL MEJOR CAMINO ENCONTRADO
    for edge in best_ant.edge_route:
        tau = g.edges[edge]['pheromone'] 
        g.edges[edge]['pheromone'] = (1 - ro) * tau + ro * (1 / best_ant.cost)

# %% [markdown]
# # Test

# %% [markdown]
# ## Greedy Test

# %%
g_ch130 = nx.read_gpickle("./build_graph/graph_ch130.gpickle")
g_a280 = nx.read_gpickle("./build_graph/graph_a280.gpickle")

g = g_a280
route, cost = greedy(g)
draw_route(g,route,cost)
g.edges[('Node_0','Node_241')]
# Out:
# (Node_0,Node_279){'distance': 17.889, 'heuristic': 0.05590027391134217, 'pheromone': 0}
# (Node_279,Node_1){'distance': 8.944, 'heuristic': 0.11180679785330946, 'pheromone': 0}
# (Node_1,Node_2){'distance': 18.439, 'heuristic': 0.05423287596941266, 'pheromone': 0}
# (Node_2,Node_278){'distance': 10.77, 'heuristic': 0.09285051067780874, 'pheromone': 0}
# (Node_278,Node_277){'distance': 8.944, 'heuristic': 0.11180679785330946, 'pheromone': 0}
# (Node_277,Node_3){'distance': 16.492, 'heuristic': 0.06063545961678389, 'pheromone': 0}
# (Node_3,Node_276){'distance': 10.0, 'heuristic': 0.1, 'pheromone': 0}
# (Node_276,Node_275){'distance': 10.77, 'heuristic': 0.09285051067780874, 'pheromone': 0}
# (Node_275,Node_274){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_274,Node_273){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_273,Node_272){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_272,Node_271){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_271,Node_270){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_270,Node_15){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_15,Node_16){'distance': 16.0, 'heuristic': 0.0625, 'pheromone': 0}
# (Node_16,Node_17){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_17,Node_18){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_18,Node_19){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_19,Node_20){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_20,Node_127){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_127,Node_126){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_126,Node_125){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_125,Node_124){'distance': 12.0, 'heuristic': 0.08333333333333333, 'pheromone': 0}
# (Node_124,Node_29){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_29,Node_30){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_30,Node_31){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_31,Node_28){'distance': 14.422, 'heuristic': 0.06933851060879212, 'pheromone': 0}
# (Node_28,Node_27){'distance': 11.314, 'heuristic': 0.088386070355312, 'pheromone': 0}
# (Node_27,Node_26){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_26,Node_25){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_25,Node_21){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_21,Node_24){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_24,Node_22){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_22,Node_23){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_23,Node_13){'distance': 16.0, 'heuristic': 0.0625, 'pheromone': 0}
# (Node_13,Node_12){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_12,Node_11){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_11,Node_10){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_10,Node_9){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_9,Node_7){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_7,Node_6){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_6,Node_8){'distance': 11.314, 'heuristic': 0.088386070355312, 'pheromone': 0}
# (Node_8,Node_5){'distance': 18.439, 'heuristic': 0.05423287596941266, 'pheromone': 0}
# (Node_5,Node_4){'distance': 10.0, 'heuristic': 0.1, 'pheromone': 0}
# (Node_4,Node_259){'distance': 42.521, 'heuristic': 0.023517791209049645, 'pheromone': 0}
# (Node_259,Node_258){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_258,Node_257){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_257,Node_256){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_256,Node_253){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_253,Node_252){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_252,Node_207){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_207,Node_206){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_206,Node_209){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_209,Node_208){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_208,Node_251){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_251,Node_254){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_254,Node_255){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_255,Node_248){'distance': 16.0, 'heuristic': 0.0625, 'pheromone': 0}
# (Node_248,Node_247){'distance': 11.314, 'heuristic': 0.088386070355312, 'pheromone': 0}
# (Node_247,Node_246){'distance': 14.422, 'heuristic': 0.06933851060879212, 'pheromone': 0}
# (Node_246,Node_243){'distance': 8.944, 'heuristic': 0.11180679785330946, 'pheromone': 0}
# (Node_243,Node_240){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_240,Node_239){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_239,Node_238){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_238,Node_237){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_237,Node_230){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_230,Node_231){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_231,Node_232){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_232,Node_233){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_233,Node_234){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_234,Node_235){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_235,Node_236){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_236,Node_245){'distance': 17.889, 'heuristic': 0.05590027391134217, 'pheromone': 0}
# (Node_245,Node_244){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_244,Node_249){'distance': 16.0, 'heuristic': 0.0625, 'pheromone': 0}
# (Node_249,Node_250){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_250,Node_229){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_229,Node_228){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_228,Node_227){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_227,Node_226){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_226,Node_225){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_225,Node_224){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_224,Node_223){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_223,Node_222){'distance': 11.314, 'heuristic': 0.088386070355312, 'pheromone': 0}
# (Node_222,Node_221){'distance': 16.0, 'heuristic': 0.0625, 'pheromone': 0}
# (Node_221,Node_218){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_218,Node_217){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_217,Node_214){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_214,Node_213){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_213,Node_210){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_210,Node_211){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_211,Node_212){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_212,Node_215){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_215,Node_216){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_216,Node_219){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_219,Node_220){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_220,Node_202){'distance': 42.521, 'heuristic': 0.023517791209049645, 'pheromone': 0}
# (Node_202,Node_201){'distance': 11.314, 'heuristic': 0.088386070355312, 'pheromone': 0}
# (Node_201,Node_199){'distance': 8.944, 'heuristic': 0.11180679785330946, 'pheromone': 0}
# (Node_199,Node_143){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_143,Node_142){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_142,Node_141){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_141,Node_140){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_140,Node_139){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_139,Node_138){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_138,Node_137){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_137,Node_136){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_136,Node_135){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_135,Node_134){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_134,Node_133){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_133,Node_269){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_269,Node_268){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_268,Node_267){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_267,Node_266){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_266,Node_265){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_265,Node_264){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_264,Node_263){'distance': 11.314, 'heuristic': 0.088386070355312, 'pheromone': 0}
# (Node_263,Node_262){'distance': 11.314, 'heuristic': 0.088386070355312, 'pheromone': 0}
# (Node_262,Node_261){'distance': 11.314, 'heuristic': 0.088386070355312, 'pheromone': 0}
# (Node_261,Node_260){'distance': 11.314, 'heuristic': 0.088386070355312, 'pheromone': 0}
# (Node_260,Node_14){'distance': 43.267, 'heuristic': 0.02311230267871588, 'pheromone': 0}
# (Node_14,Node_132){'distance': 40.0, 'heuristic': 0.025, 'pheromone': 0}
# (Node_132,Node_131){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_131,Node_130){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_130,Node_129){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_129,Node_128){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_128,Node_153){'distance': 14.422, 'heuristic': 0.06933851060879212, 'pheromone': 0}
# (Node_153,Node_154){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_154,Node_152){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_152,Node_155){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_155,Node_151){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_151,Node_150){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_150,Node_176){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_176,Node_175){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_175,Node_180){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_180,Node_179){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_179,Node_178){'distance': 8.944, 'heuristic': 0.11180679785330946, 'pheromone': 0}
# (Node_178,Node_177){'distance': 17.889, 'heuristic': 0.05590027391134217, 'pheromone': 0}
# (Node_177,Node_149){'distance': 16.492, 'heuristic': 0.06063545961678389, 'pheromone': 0}
# (Node_149,Node_148){'distance': 16.492, 'heuristic': 0.06063545961678389, 'pheromone': 0}
# (Node_148,Node_147){'distance': 8.944, 'heuristic': 0.11180679785330946, 'pheromone': 0}
# (Node_147,Node_146){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_146,Node_145){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_145,Node_144){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_144,Node_198){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_198,Node_197){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_197,Node_196){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_196,Node_193){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_193,Node_194){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_194,Node_195){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_195,Node_200){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_200,Node_192){'distance': 26.833, 'heuristic': 0.037267543696194984, 'pheromone': 0}
# (Node_192,Node_191){'distance': 17.088, 'heuristic': 0.05852059925093633, 'pheromone': 0}
# (Node_191,Node_190){'distance': 14.0, 'heuristic': 0.07142857142857142, 'pheromone': 0}
# (Node_190,Node_189){'distance': 12.0, 'heuristic': 0.08333333333333333, 'pheromone': 0}
# (Node_189,Node_188){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_188,Node_187){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_187,Node_186){'distance': 12.649, 'heuristic': 0.07905763301446755, 'pheromone': 0}
# (Node_186,Node_184){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_184,Node_183){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_183,Node_182){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_182,Node_181){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_181,Node_160){'distance': 20.396, 'heuristic': 0.049029221415963914, 'pheromone': 0}
# (Node_160,Node_161){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_161,Node_162){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_162,Node_163){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_163,Node_164){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_164,Node_165){'distance': 14.422, 'heuristic': 0.06933851060879212, 'pheromone': 0}
# (Node_165,Node_166){'distance': 12.0, 'heuristic': 0.08333333333333333, 'pheromone': 0}
# (Node_166,Node_167){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_167,Node_168){'distance': 14.422, 'heuristic': 0.06933851060879212, 'pheromone': 0}
# (Node_168,Node_100){'distance': 8.944, 'heuristic': 0.11180679785330946, 'pheromone': 0}
# (Node_100,Node_99){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_99,Node_98){'distance': 12.166, 'heuristic': 0.0821962847279303, 'pheromone': 0}
# (Node_98,Node_97){'distance': 13.416, 'heuristic': 0.07453786523553965, 'pheromone': 0}
# (Node_97,Node_92){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_92,Node_93){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_93,Node_94){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_94,Node_95){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_95,Node_96){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_96,Node_91){'distance': 22.361, 'heuristic': 0.044720719109163275, 'pheromone': 0}
# (Node_91,Node_90){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_90,Node_89){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_89,Node_88){'distance': 8.944, 'heuristic': 0.11180679785330946, 'pheromone': 0}
# (Node_88,Node_108){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_108,Node_107){'distance': 8.246, 'heuristic': 0.12127091923356778, 'pheromone': 0}
# (Node_107,Node_103){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_103,Node_102){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_102,Node_101){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_101,Node_169){'distance': 16.0, 'heuristic': 0.0625, 'pheromone': 0}
# (Node_169,Node_170){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_170,Node_171){'distance': 0.0, 'heuristic': 0, 'pheromone': 0}
# (Node_171,Node_172){'distance': 16.0, 'heuristic': 0.0625, 'pheromone': 0}
# (Node_172,Node_105){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_105,Node_104){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_104,Node_106){'distance': 11.314, 'heuristic': 0.088386070355312, 'pheromone': 0}
# (Node_106,Node_173){'distance': 16.0, 'heuristic': 0.0625, 'pheromone': 0}
# (Node_173,Node_174){'distance': 17.889, 'heuristic': 0.05590027391134217, 'pheromone': 0}
# (Node_174,Node_159){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_159,Node_158){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_158,Node_157){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_157,Node_156){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_156,Node_118){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_118,Node_119){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_119,Node_120){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_120,Node_121){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_121,Node_122){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_122,Node_123){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_123,Node_33){'distance': 31.241, 'heuristic': 0.03200921865497263, 'pheromone': 0}
# (Node_33,Node_32){'distance': 12.806, 'heuristic': 0.07808839606434484, 'pheromone': 0}
# (Node_32,Node_35){'distance': 26.0, 'heuristic': 0.038461538461538464, 'pheromone': 0}
# (Node_35,Node_34){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_34,Node_37){'distance': 8.944, 'heuristic': 0.11180679785330946, 'pheromone': 0}
# (Node_37,Node_36){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_36,Node_38){'distance': 16.0, 'heuristic': 0.0625, 'pheromone': 0}
# (Node_38,Node_39){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_39,Node_40){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_40,Node_41){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_41,Node_42){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_42,Node_59){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_59,Node_60){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_60,Node_117){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_117,Node_116){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_116,Node_114){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_114,Node_113){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_113,Node_110){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_110,Node_109){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_109,Node_111){'distance': 10.0, 'heuristic': 0.1, 'pheromone': 0}
# (Node_111,Node_87){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_87,Node_82){'distance': 8.246, 'heuristic': 0.12127091923356778, 'pheromone': 0}
# (Node_82,Node_81){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_81,Node_80){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_80,Node_79){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_79,Node_78){'distance': 8.944, 'heuristic': 0.11180679785330946, 'pheromone': 0}
# (Node_78,Node_75){'distance': 14.422, 'heuristic': 0.06933851060879212, 'pheromone': 0}
# (Node_75,Node_74){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_74,Node_73){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_73,Node_72){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_72,Node_71){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_71,Node_70){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_70,Node_69){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_69,Node_66){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_66,Node_65){'distance': 11.314, 'heuristic': 0.088386070355312, 'pheromone': 0}
# (Node_65,Node_64){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_64,Node_63){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_63,Node_62){'distance': 8.246, 'heuristic': 0.12127091923356778, 'pheromone': 0}
# (Node_62,Node_61){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_61,Node_115){'distance': 16.0, 'heuristic': 0.0625, 'pheromone': 0}
# (Node_115,Node_85){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_85,Node_84){'distance': 8.246, 'heuristic': 0.12127091923356778, 'pheromone': 0}
# (Node_84,Node_83){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_83,Node_86){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_86,Node_112){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_112,Node_58){'distance': 40.792, 'heuristic': 0.024514610707981957, 'pheromone': 0}
# (Node_58,Node_43){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_43,Node_44){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_44,Node_45){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_45,Node_46){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_46,Node_47){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_47,Node_48){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_48,Node_49){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_49,Node_50){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_50,Node_51){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_51,Node_52){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_52,Node_53){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_53,Node_54){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_54,Node_55){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_55,Node_56){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_56,Node_57){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_57,Node_67){'distance': 16.492, 'heuristic': 0.06063545961678389, 'pheromone': 0}
# (Node_67,Node_68){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_68,Node_76){'distance': 60.0, 'heuristic': 0.016666666666666666, 'pheromone': 0}
# (Node_76,Node_77){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# (Node_77,Node_185){'distance': 125.603, 'heuristic': 0.007961593274046002, 'pheromone': 0}
# (Node_185,Node_203){'distance': 80.498, 'heuristic': 0.012422668886183506, 'pheromone': 0}
# (Node_203,Node_204){'distance': 11.314, 'heuristic': 0.088386070355312, 'pheromone': 0}
# (Node_204,Node_205){'distance': 11.314, 'heuristic': 0.088386070355312, 'pheromone': 0}
# (Node_205,Node_242){'distance': 69.971, 'heuristic': 0.014291635105972474, 'pheromone': 0}
# (Node_242,Node_241){'distance': 8.0, 'heuristic': 0.125, 'pheromone': 0}
# {'distance': 40.0, 'heuristic': 0.025, 'pheromone': 0}

# %% [markdown]
# ## SH Test

# %%
g_ch130 = nx.read_gpickle("./build_graph/graph_ch130.gpickle")
g_a280 = nx.read_gpickle("./build_graph/graph_a280.gpickle")

g = g_ch130
n = 3
m = 10
alpha = 1
beta = 2
ro = 0.1
display = False
route, cost, ev = sh(0,g,n,m,alpha,beta,ro,display)
draw_route(g,route,cost)
draw_pheromones_by_node(g, 8)

# %%
draw_route(g,route,cost)
draw_pheromones_by_node(g, 8)
#draw_pheromones(g)
# Out:
# Tiempo: 0.01951743761698405 min

# %% [markdown]
# ## SHE Test

# %%
g_ch130 = nx.read_gpickle("./build_graph/graph_ch130.gpickle")
g_a280 = nx.read_gpickle("./build_graph/graph_a280.gpickle")

g = g_a280
n = 3
m = 10
alpha = 1
beta = 2
ro = 0.1
elite = 15
display = True
route, cost, ev = she(0,g,n,m,alpha,beta,ro,elite,display)
draw_route(g,route,cost)
# Out:
# Init SH solution: 3108.109 km
# Iteracion 0
# Iteracion 1
# Iteracion 2
# Iteracion 3
# Iteracion 4
# Iteracion 5
# Iteracion 6
# Iteracion 7
# Iteracion 8
# Iteracion 9
# Iteracion 10
# Iteracion 11
# Iteracion 12
# Iteracion 13
# Iteracion 14
# Iteracion 15
# Iteracion 16
# Iteracion 17
# Iteracion 18
# Iteracion 19
# Iteracion 20
# Iteracion 21
# Iteracion 22
# Iteracion 23
# Iteracion 24
# Iteracion 25
# Iteracion 26
# Iteracion 27
# Iteracion 28
# Iteracion 29
# Iteracion 30
# Iteracion 31
# Iteracion 32

# %% [markdown]
# ## SCH Test

# %%
g_ch130 = nx.read_gpickle("./build_graph/graph_ch130.gpickle")
g_a280 = nx.read_gpickle("./build_graph/graph_a280.gpickle")

g = g_a280
n = 3
m = 10
alpha = 1
beta = 2
ro = 0.1
q0 = 0.98
fi = 0.1
display = True
route, cost, ev = sch(0,g,n,m,alpha,beta,ro,q0,fi,display)
draw_route(g,route,cost)
# Out:
# Init SCH solution: 3108.109 km
# Iteracion 0 - Best actual ant cost: 3108.4159999999997
# Iteracion 1 - Best actual ant cost: 3108.4159999999997
# Iteracion 2 - Best actual ant cost: 3108.4159999999997
# Iteracion 3 - Best actual ant cost: 3108.4159999999997
# Iteracion 4 - Best actual ant cost: 3108.4159999999997
# Iteracion 5 - Best actual ant cost: 3108.4159999999997
# Iteracion 6 - Best actual ant cost: 3108.4159999999997
# Iteracion 7 - Best actual ant cost: 3108.4159999999997
# Iteracion 8 - Best actual ant cost: 3108.4159999999997
# Iteracion 9 - Best actual ant cost: 3108.4159999999997
# Iteracion 10 - Best actual ant cost: 3108.4159999999997
# Iteracion 11 - Best actual ant cost: 3108.4159999999997
# Iteracion 12 - Best actual ant cost: 3108.4159999999997
# Iteracion 13 - Best actual ant cost: 3108.4159999999997
# Iteracion 14 - Best actual ant cost: 3108.4159999999997
# Iteracion 15 - Best actual ant cost: 3108.4159999999997
# Iteracion 16 - Best actual ant cost: 3108.4159999999997
# Iteracion 17 - Best actual ant cost: 3108.4159999999997
# Iteracion 18 - Best actual ant cost: 3108.4159999999997
# Iteracion 19 - Best actual ant cost: 3108.4159999999997
# Iteracion 20 - Best actual ant cost: 3108.4159999999997
# Iteracion 21 - Best actual ant cost: 3108.4159999999997
# Iteracion 22 - Best actual ant cost: 3108.4159999999997
# Iteracion 23 - Best actual ant cost: 3108.4159999999997
# Iteracion 24 - Best actual ant cost: 3108.4159999999997
# Iteracion 25 - Best actual ant cost: 3108.4159999999997
# Iteracion 26 - Best actual ant cost: 3108.4159999999997
# Iteracion 27 - Best actual ant cost: 3108.4159999999997
# Iteracion 28 - Best actual ant cost: 3108.4159999999997
# Iteracion 29 - Best actual ant cost: 3108.4159999999997
# Iteracion 30 - Best actual ant cost: 3108.4159999999997
# Iteracion 31 - Best actual ant cost: 3108.4159999999997
# Iteracion 32 - Best actual ant cost: 3108.4159999999997
# Iteracion 33 - Best actual ant cost: 3108.4159999999997
# Iteracion 34 - Best actual ant cost: 3108.4159999999997
# Iteracion 35 - Best actual ant cost: 3108.4159999999997
# Iteracion 36 - Best actual ant cost: 3108.4159999999997
# Iteracion 37 - Best actual ant cost: 3108.4159999999997
# Iteracion 38 - Best actual ant cost: 3108.4159999999997
# Iteracion 39 - Best actual ant cost: 3108.4159999999997
# Iteracion 40 - Best actual ant cost: 3108.4159999999997
# Iteracion 41 - Best actual ant cost: 3108.4159999999997
# Iteracion 42 - Best actual ant cost: 3108.4159999999997
# Iteracion 43 - Best actual ant cost: 3108.4159999999997
# Iteracion 44 - Best actual ant cost: 3108.4159999999997
# Iteracion 45 - Best actual ant cost: 3108.4159999999997
# Iteracion 46 - Best actual ant cost: 3108.4159999999997
# Iteracion 47 - Best actual ant cost: 3108.4159999999997
# Iteracion 48 - Best actual ant cost: 3108.4159999999997
# Iteracion 49 - Best actual ant cost: 3108.4159999999997
# Iteracion 50 - Best actual ant cost: 3108.4159999999997
# Iteracion 51 - Best actual ant cost: 3108.4159999999997
# Iteracion 52 - Best actual ant cost: 3108.4159999999997
# Iteracion 53 - Best actual ant cost: 3108.4159999999997
# Iteracion 54 - Best actual ant cost: 3108.4159999999997
# Iteracion 55 - Best actual ant cost: 3108.4159999999997
# Iteracion 56 - Best actual ant cost: 3108.4159999999997
# Iteracion 57 - Best actual ant cost: 3108.4159999999997
# Iteracion 58 - Best actual ant cost: 3108.4159999999997
# Iteracion 59 - Best actual ant cost: 3108.4159999999997
# Iteracion 60 - Best actual ant cost: 3108.4159999999997
# Iteracion 61 - Best actual ant cost: 3108.4159999999997
# Iteracion 62 - Best actual ant cost: 3108.4159999999997
# Iteracion 63 - Best actual ant cost: 3108.4159999999997
# Iteracion 64 - Best actual ant cost: 3108.4159999999997
# Iteracion 65 - Best actual ant cost: 3108.4159999999997
# Iteracion 66 - Best actual ant cost: 3108.4159999999997
# Iteracion 67 - Best actual ant cost: 3108.4159999999997
# Iteracion 68 - Best actual ant cost: 3108.4159999999997
# Iteracion 69 - Best actual ant cost: 3108.4159999999997
# Iteracion 70 - Best actual ant cost: 3108.4159999999997
# Iteracion 71 - Best actual ant cost: 3108.4159999999997
# Iteracion 72 - Best actual ant cost: 3108.4159999999997
# Iteracion 73 - Best actual ant cost: 3108.4159999999997
# Iteracion 74 - Best actual ant cost: 3108.4159999999997
# Iteracion 75 - Best actual ant cost: 3108.4159999999997
# Iteracion 76 - Best actual ant cost: 3108.4159999999997
# Iteracion 77 - Best actual ant cost: 3108.4159999999997
# Iteracion 78 - Best actual ant cost: 3108.4159999999997
# Iteracion 79 - Best actual ant cost: 3108.4159999999997
# Iteracion 80 - Best actual ant cost: 3108.4159999999997
# Iteracion 81 - Best actual ant cost: 3108.4159999999997
# Iteracion 82 - Best actual ant cost: 3108.4159999999997
# Iteracion 83 - Best actual ant cost: 3108.4159999999997
# Iteracion 84 - Best actual ant cost: 3108.4159999999997
# Iteracion 85 - Best actual ant cost: 3108.4159999999997
# Iteracion 86 - Best actual ant cost: 3108.4159999999997
# Iteracion 87 - Best actual ant cost: 3108.4159999999997
# Iteracion 88 - Best actual ant cost: 3108.4159999999997
# Iteracion 89 - Best actual ant cost: 3108.4159999999997
# Iteracion 90 - Best actual ant cost: 3108.4159999999997
# Iteracion 91 - Best actual ant cost: 3108.4159999999997
# Iteracion 92 - Best actual ant cost: 3108.4159999999997
# Iteracion 93 - Best actual ant cost: 3108.4159999999997
# Iteracion 94 - Best actual ant cost: 3108.4159999999997
# Iteracion 95 - Best actual ant cost: 3108.4159999999997
# Iteracion 96 - Best actual ant cost: 3108.4159999999997
# Iteracion 97 - Best actual ant cost: 3108.4159999999997
# Iteracion 98 - Best actual ant cost: 3108.4159999999997
# Iteracion 99 - Best actual ant cost: 3108.4159999999997
# Iteracion 100 - Best actual ant cost: 3108.4159999999997
# Iteracion 101 - Best actual ant cost: 3108.4159999999997
# Iteracion 102 - Best actual ant cost: 3108.4159999999997
# Iteracion 103 - Best actual ant cost: 3108.4159999999997
# Iteracion 104 - Best actual ant cost: 3108.4159999999997
# Iteracion 105 - Best actual ant cost: 3108.4159999999997
# Iteracion 106 - Best actual ant cost: 3108.4159999999997
# Iteracion 107 - Best actual ant cost: 3108.4159999999997
# Iteracion 108 - Best actual ant cost: 3108.4159999999997
# Iteracion 109 - Best actual ant cost: 3108.4159999999997
# Iteracion 110 - Best actual ant cost: 3108.4159999999997
# Iteracion 111 - Best actual ant cost: 3108.4159999999997
# Iteracion 112 - Best actual ant cost: 3108.4159999999997
# Iteracion 113 - Best actual ant cost: 3108.4159999999997
# Iteracion 114 - Best actual ant cost: 3108.4159999999997
# Iteracion 115 - Best actual ant cost: 3108.4159999999997
# Iteracion 116 - Best actual ant cost: 3108.4159999999997
# Iteracion 117 - Best actual ant cost: 3108.4159999999997
# Iteracion 118 - Best actual ant cost: 3108.4159999999997
# Iteracion 119 - Best actual ant cost: 3108.4159999999997
# Iteracion 120 - Best actual ant cost: 3108.4159999999997
# Iteracion 121 - Best actual ant cost: 3108.4159999999997
# Iteracion 122 - Best actual ant cost: 3108.4159999999997
# Iteracion 123 - Best actual ant cost: 3108.4159999999997
# Iteracion 124 - Best actual ant cost: 3108.4159999999997
# Iteracion 125 - Best actual ant cost: 3108.4159999999997
# Iteracion 126 - Best actual ant cost: 3108.4159999999997
# Iteracion 127 - Best actual ant cost: 3108.4159999999997
# Iteracion 128 - Best actual ant cost: 3108.4159999999997
# Iteracion 129 - Best actual ant cost: 3108.4159999999997
# Iteracion 130 - Best actual ant cost: 3108.4159999999997
# Iteracion 131 - Best actual ant cost: 3108.4159999999997
# Iteracion 132 - Best actual ant cost: 3108.4159999999997
# Iteracion 133 - Best actual ant cost: 3108.4159999999997
# Iteracion 134 - Best actual ant cost: 3108.4159999999997
# Iteracion 135 - Best actual ant cost: 3108.4159999999997
# Iteracion 136 - Best actual ant cost: 3108.4159999999997
# Iteracion 137 - Best actual ant cost: 3108.4159999999997
# Iteracion 138 - Best actual ant cost: 3108.4159999999997
# Iteracion 139 - Best actual ant cost: 3108.4159999999997
# Iteracion 140 - Best actual ant cost: 3108.4159999999997
# Iteracion 141 - Best actual ant cost: 3108.4159999999997
# Iteracion 142 - Best actual ant cost: 3108.4159999999997
# Iteracion 143 - Best actual ant cost: 3108.4159999999997
# Iteracion 144 - Best actual ant cost: 3108.4159999999997
# Iteracion 145 - Best actual ant cost: 3108.4159999999997
# Iteracion 146 - Best actual ant cost: 3108.4159999999997
# Iteracion 147 - Best actual ant cost: 3108.4159999999997
# Iteracion 148 - Best actual ant cost: 3108.4159999999997
# Iteracion 149 - Best actual ant cost: 3108.4159999999997
# Iteracion 150 - Best actual ant cost: 3108.4159999999997
# Iteracion 151 - Best actual ant cost: 3108.4159999999997
# Iteracion 152 - Best actual ant cost: 3108.4159999999997
# Iteracion 153 - Best actual ant cost: 3108.4159999999997
# Iteracion 154 - Best actual ant cost: 3108.4159999999997
# Iteracion 155 - Best actual ant cost: 3108.4159999999997
# Iteracion 156 - Best actual ant cost: 3108.4159999999997
# Iteracion 157 - Best actual ant cost: 3108.4159999999997
# Iteracion 158 - Best actual ant cost: 3108.4159999999997
# Iteracion 159 - Best actual ant cost: 3108.4159999999997
# Iteracion 160 - Best actual ant cost: 3108.4159999999997
# Iteracion 161 - Best actual ant cost: 3108.4159999999997
# Iteracion 162 - Best actual ant cost: 3108.4159999999997
# Iteracion 163 - Best actual ant cost: 3108.4159999999997
# Iteracion 164 - Best actual ant cost: 3108.4159999999997
# Iteracion 165 - Best actual ant cost: 3108.4159999999997
# Iteracion 166 - Best actual ant cost: 3108.4159999999997
# Iteracion 167 - Best actual ant cost: 3108.4159999999997
# Iteracion 168 - Best actual ant cost: 3108.4159999999997
# Iteracion 169 - Best actual ant cost: 3108.4159999999997
# Iteracion 170 - Best actual ant cost: 3108.4159999999997
# Iteracion 171 - Best actual ant cost: 3108.4159999999997
# Iteracion 172 - Best actual ant cost: 3108.4159999999997
# Iteracion 173 - Best actual ant cost: 3108.4159999999997
# Iteracion 174 - Best actual ant cost: 3108.4159999999997
# Iteracion 175 - Best actual ant cost: 3108.4159999999997
# Iteracion 176 - Best actual ant cost: 3108.4159999999997
# Iteracion 177 - Best actual ant cost: 3108.4159999999997
# Iteracion 178 - Best actual ant cost: 3108.4159999999997
# Iteracion 179 - Best actual ant cost: 3108.4159999999997
# Iteracion 180 - Best actual ant cost: 3108.4159999999997
# Iteracion 181 - Best actual ant cost: 3108.4159999999997
# Iteracion 182 - Best actual ant cost: 3108.4159999999997
# Iteracion 183 - Best actual ant cost: 3108.4159999999997
# Iteracion 184 - Best actual ant cost: 3108.4159999999997
# Iteracion 185 - Best actual ant cost: 3108.4159999999997
# Iteracion 186 - Best actual ant cost: 3108.4159999999997
# Iteracion 187 - Best actual ant cost: 3108.4159999999997
# Iteracion 188 - Best actual ant cost: 3108.4159999999997
# Iteracion 189 - Best actual ant cost: 3108.4159999999997
# Iteracion 190 - Best actual ant cost: 3108.4159999999997
# Iteracion 191 - Best actual ant cost: 3108.4159999999997
# Iteracion 192 - Best actual ant cost: 3108.4159999999997
# Iteracion 193 - Best actual ant cost: 3108.4159999999997
# Iteracion 194 - Best actual ant cost: 3108.4159999999997
# Iteracion 195 - Best actual ant cost: 3108.4159999999997
# Iteracion 196 - Best actual ant cost: 3108.4159999999997
# Iteracion 197 - Best actual ant cost: 3108.4159999999997
# Iteracion 198 - Best actual ant cost: 3108.4159999999997
# Iteracion 199 - Best actual ant cost: 3108.4159999999997
# Iteracion 200 - Best actual ant cost: 3108.4159999999997
# Iteracion 201 - Best actual ant cost: 3108.4159999999997
# Iteracion 202 - Best actual ant cost: 3108.4159999999997
# Iteracion 203 - Best actual ant cost: 3108.4159999999997
# Iteracion 204 - Best actual ant cost: 3108.4159999999997
# Iteracion 205 - Best actual ant cost: 3108.4159999999997
# Iteracion 206 - Best actual ant cost: 3108.4159999999997
# Iteracion 207 - Best actual ant cost: 3108.4159999999997
# Iteracion 208 - Best actual ant cost: 3108.4159999999997
# Iteracion 209 - Best actual ant cost: 3108.4159999999997
# Iteracion 210 - Best actual ant cost: 3108.4159999999997
# Iteracion 211 - Best actual ant cost: 3108.4159999999997
# Iteracion 212 - Best actual ant cost: 3108.4159999999997
# Iteracion 213 - Best actual ant cost: 3108.4159999999997
# Iteracion 214 - Best actual ant cost: 3108.4159999999997
# Iteracion 215 - Best actual ant cost: 3108.4159999999997
# Iteracion 216 - Best actual ant cost: 3108.4159999999997
# Iteracion 217 - Best actual ant cost: 3108.4159999999997
# Iteracion 218 - Best actual ant cost: 3108.4159999999997
# Iteracion 219 - Best actual ant cost: 3108.4159999999997
# Iteracion 220 - Best actual ant cost: 3108.4159999999997

# %% [markdown]
# # Pruebas

# %%
# Import Libraries

import numpy as np
import matplotlib.pyplot as plt


# Create figure and subplot

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1) 

# Define and update plot

for i in range(20):
    x = np.linspace(0, i, 100);
    y = np.cos(x) 
    ax.set_xlim(0, i)    
    ax.cla()
    ax.plot(x, y)
    display(fig)    
    clear_output(wait = True)
    plt.pause(0.01)

# %%
# Import Libraries

import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, clear_output

# Create figure and subplot

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1) 

# Define and update plot

for i in range(100):
    ax.set_xlim(0, 50)
    ax.plot(i, 2, marker='o')
    display(fig)    
    clear_output(wait = True)
    plt.pause(0.001)
